# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Loading Dataset

HousingDF = pd.read_csv('train.csv')

# %%
HousingDF_test = pd.read_csv('test.csv')

# %%
HousingDF.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   127         120       RL          NaN     4928   Pave   NaN      IR1
# 1   889          20       RL         95.0    15865   Pave   NaN      IR1
# 2   793          60       RL         92.0     9920   Pave   NaN      IR1
# 3   110          20       RL        105.0    11751   Pave   NaN      IR1
# 4   422          20       RL          NaN    16635   Pave   NaN      IR1
# 5  1197          60       RL         58.0    14054   Pave   NaN      IR1
# 6   561          20       RL          NaN    11341   Pave   NaN      IR1
# 7  1041          20       RL         88.0    13125   Pave   NaN      Reg
# 8   503          20       RL         70.0     9170   Pave   NaN      Reg
# 9   576          50       RL         80.0     8480   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 5         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 6         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 7         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 8         Lvl    AllPub  ...        0    NaN  GdPrv        Shed     400
# 9         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2007        WD         Normal     128000
# 1     10   2007        WD         Normal     268000
# 2      6   2007        WD         Normal     269790
# 3      1   2010       COD         Normal     190000
# 4      6   2009        WD         Normal     215000
# 5     11   2006       New        Partial     219210
# 6      5   2010        WD         Normal     121500
# 7      1   2006        WD         Normal     155000
# 8      4   2007        WD         Normal     140000
# 9     10   2008       COD        Abnorml     118500
#
# [10 rows x 81 columns]

# %%
HousingDF_test.head(10)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
# 5   650         180       RM         21.0     1936   Pave   NaN      Reg
# 6  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 7   152          20       RL        107.0    13891   Pave   NaN      Reg
# 8   427          80       RL          NaN    12800   Pave   NaN      Reg
# 9   776         120       RM         32.0     4500   Pave   NaN      Reg
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         HLS    AllPub  ...           0        0    NaN    NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 3         Bnk    AllPub  ...           0        0    NaN    NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 5         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 6         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 7         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 8         Low    AllPub  ...         396        0    NaN    NaN         NaN
# 9         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      7    2007        WD         Normal
# 1       0      8    2009       COD        Abnorml
# 2       0      6    2009        WD         Normal
# 3       0      7    2009        WD         Normal
# 4       0      1    2008        WD         Normal
# 5       0     12    2007        WD         Normal
# 6       0      5    2006        WD         Normal
# 7       0      1    2008       New        Partial
# 8       0      8    2009        WD         Normal
# 9       0      6    2009        WD         Normal
#
# [10 rows x 80 columns]

# %%
# checking the column missing from the test dataset

HousingDF.columns.difference(HousingDF_test.columns)
# Out:
# Index(['SalePrice'], dtype='object')

# %% [markdown]
# # DataSet Discription
#
# Houses are one of the necessary need of each and every person around the globe and therefore housing and real estate
# market is one of the markets which is one of the major contributors in the world’s economy. It is a very large market
# and there are various companies working in the domain. Data science comes as a very important tool to solve problems
# in the domain to help the companies increase their overall revenue, profits, improving their marketing strategies and
# focusing on changing trends in house sales and purchases. Predictive modelling, Market mix modelling,
# recommendation systems are some of the machine learning techniques used for achieving the business goals for housing
# companies. Our problem is related to one such housing company.
# A US-based housing company named Surprise Housing has decided to enter the Australian market. The company uses
# data analytics to purchase houses at a price below their actual values and flip them at a higher price. For the same
# purpose, the company has collected a data set from the sale of houses in Australia. The data is provided in the CSV file
# below.
# The company is looking at prospective properties to buy houses to enter the market. You are required to build a model
# using Machine Learning in order to predict the actual value of the prospective properties and decide whether to invest
# in them or not. For this company wants to know:
#
# • Which variables are important to predict the price of variable?
#
# • How do these variables describe the price of the house?
#
# # Business Goal
#
# This model will then be used by the management to understand how exactly the prices vary with the variables. They can accordingly manipulate the strategy of the firm and concentrate on areas that will yield high returns. Further, the model will be a good way for the management to understand the pricing dynamics of a new market.
#
# Data contains 1460 entries each having 81 variables.
#
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
# MSZoning: Identifies the general zoning classification of the sale.
#
# LotFrontage: Linear feet of street connected to property
#
# LotArea: Lot size in square feet
#
# Street: Type of road access to property
#
# Alley: Type of alley access to property
#
# LotShape: General shape of property
#
# LandContour: Flatness of the property
#
# Utilities: Type of utilities available
#
# LotConfig: Lot configuration
#
# LandSlope: Slope of property
#
# Neighborhood: Physical locations within Ames city limits
#
# Condition1: Proximity to various conditions
#
# Condition2: Proximity to various conditions (if more than one is present)
#
# BldgType: Type of dwelling
#
# HouseStyle: Style of dwelling
#
# OverallQual: Rates the overall material and finish of the house
#
# OverallCond: Rates the overall condition of the house
#
# YearBuilt: Original construction date
#
# YearRemodAdd: Remodel date (same as construction date if no remodeling or additions)
#
# RoofStyle: Type of roof
#
# RoofMatl: Roof material
#
# Exterior1st: Exterior covering on house
#
# Exterior2nd: Exterior covering on house (if more than one material)
#
# MasVnrType: Masonry veneer type
#
# MasVnrArea: Masonry veneer area in square feet
#
# ExterQual: Evaluates the quality of the material on the exterior
#
# ExterCond: Evaluates the present condition of the material on the exterior
#
# Foundation: Type of foundation
#
# BsmtQual: Evaluates the height of the basement
#
# BsmtCond: Evaluates the general condition of the basement
#
# BsmtExposure: Refers to walkout or garden level walls
#
# BsmtFinType1: Rating of basement finished area
#
# BsmtFinSF1: Type 1 finished square feet
#
# BsmtFinType2: Rating of basement finished area (if multiple types)
#
# BsmtFinSF2: Type 2 finished square feet
#
# BsmtUnfSF: Unfinished square feet of basement area
#
# TotalBsmtSF: Total square feet of basement area
#
# Heating: Type of heating
#
# HeatingQC: Heating quality and condition
#
# CentralAir: Central air conditioning
#
# Electrical: Electrical system
#
# 1stFlrSF: First Floor square feet
#
# 2ndFlrSF: Second floor square feet
#
# LowQualFinSF: Low quality finished square feet (all floors)
#
# GrLivArea: Above grade (ground) living area square feet
#
# BsmtFullBath: Basement full bathrooms
#
# BsmtHalfBath: Basement half bathrooms
#
# FullBath: Full bathrooms above grade
#
# HalfBath: Half baths above grade
#
# Bedroom: Bedrooms above grade (does NOT include basement bedrooms)
#
# Kitchen: Kitchens above grade
#
# KitchenQual: Kitchen quality
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
# GarageType: Garage location
#
# GarageYrBlt: Year garage was built
#
# GarageFinish: Interior finish of the garage
#
# GarageCars: Size of garage in car capacity
#
# GarageArea: Size of garage in square feet
#
# GarageQual: Garage quality
#
# GarageCond: Garage condition
#
# PavedDrive: Paved driveway
#
# WoodDeckSF: Wood deck area in square feet
#
# OpenPorchSF: Open porch area in square feet
#
# EnclosedPorch: Enclosed porch area in square feet
#
# 3SsnPorch: Three season porch area in square feet
#
# ScreenPorch: Screen porch area in square feet
#
# PoolArea: Pool area in square feet
#
# PoolQC: Pool quality
#
# Fence: Fence quality
#
# MiscFeature: Miscellaneous feature not covered in other categories
#
# MiscVal: $Value of miscellaneous feature
#
# MoSold: Month Sold (MM)
#
# YrSold: Year Sold (YYYY)
#
# SaleType: Type of sale
#
# SaleCondition: Condition of sale
#
# # Target Column - Sales Price
#
# # Checking Null Values

# %%
HousingDF[HousingDF.columns[HousingDF.isnull().any()]]
# Out:
#       LotFrontage Alley MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure  \
# 0             NaN   NaN       None         0.0       Gd       TA           No
# 1            95.0   NaN       None         0.0       TA       Gd           Gd
# 2            92.0   NaN       None         0.0       Gd       TA           Av
# 3           105.0   NaN    BrkFace       480.0       Gd       TA           No
# 4             NaN   NaN      Stone       126.0       Gd       TA           No
# ...           ...   ...        ...         ...      ...      ...          ...
# 1163          NaN   NaN    BrkFace        31.0       TA       TA           No
# 1164         67.0   NaN       None         0.0      NaN      NaN          NaN
# 1165         24.0   NaN       None         0.0       Gd       TA           No
# 1166         50.0  Pave       None         0.0       TA       TA           No
# 1167          NaN   NaN       None         0.0       Gd       TA           No
#
#      BsmtFinType1 BsmtFinType2 FireplaceQu GarageType  GarageYrBlt  \
# 0             ALQ          Unf          TA     Attchd       1977.0
# 1             ALQ          Rec          TA     Attchd       1970.0
# 2             GLQ          Unf          TA     Attchd       1997.0
# 3             BLQ          Unf          TA     Attchd       1977.0
# 4             ALQ          Unf          TA     Attchd       1977.0
# ...           ...          ...         ...        ...          ...
# 1163          BLQ          Unf         NaN     Detchd       1970.0
# 1164          NaN          NaN         NaN     Detchd       2002.0
# 1165          ALQ          Unf          TA     Attchd       1976.0
# 1166          Unf          Unf         NaN     Detchd       1920.0
# 1167          GLQ          Unf          Gd     Attchd       2002.0
#
#      GarageFinish GarageQual GarageCond PoolQC  Fence MiscFeature
# 0             RFn         TA         TA    NaN    NaN         NaN
# 1             Unf         TA         TA    NaN    NaN         NaN
# 2             Unf         TA         TA    NaN    NaN         NaN
# 3             RFn         TA         TA    NaN  MnPrv         NaN
# 4             Fin         TA         TA    NaN    NaN         NaN
# ...           ...        ...        ...    ...    ...         ...
# 1163          Unf         TA         TA    NaN  MnPrv         NaN
# 1164          Fin         TA         TA    NaN  MnPrv         NaN
# 1165          Unf         TA         TA    NaN    NaN         NaN
# 1166          Unf         TA         Fa    NaN  MnPrv         NaN
# 1167          Fin         TA         TA    NaN    NaN         NaN
#
# [1168 rows x 18 columns]

# %% [markdown]
# There are 18 columns in Train dataset with null values

# %%
# Checking null columns in test dataset

HousingDF_test[HousingDF_test.columns[HousingDF_test.isnull().any()]]
# Out:
#      LotFrontage Alley MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure  \
# 0           86.0   NaN      Stone       200.0       Ex       TA           Gd
# 1            NaN   NaN       None         0.0       Gd       TA           Av
# 2            NaN   NaN       None         0.0       Gd       TA           Av
# 3           75.0   NaN       None         0.0       TA       TA           No
# 4           86.0   NaN      Stone        74.0       Gd       TA           Mn
# ..           ...   ...        ...         ...      ...      ...          ...
# 287         78.0   NaN      Stone       468.0       Gd       TA           No
# 288         57.0   NaN       None         0.0       Gd       TA           No
# 289          NaN   NaN    BrkFace       180.0       TA       TA           No
# 290         50.0   NaN       None         0.0       TA       TA           No
# 291         21.0   NaN    BrkFace       408.0       TA       Fa           No
#
#     BsmtFinType1 BsmtFinType2 Electrical FireplaceQu GarageType  GarageYrBlt  \
# 0            GLQ          Unf      SBrkr          Gd     Attchd       2005.0
# 1            GLQ          Unf      SBrkr          Ex     Attchd       1984.0
# 2            Unf          Unf      SBrkr          TA     Attchd       2001.0
# 3            Rec          Unf      SBrkr          Gd     Attchd       1941.0
# 4            Unf          Unf      SBrkr          Gd    BuiltIn       2007.0
# ..           ...          ...        ...         ...        ...          ...
# 287          GLQ          Unf      SBrkr          Gd     Attchd       2007.0
# 288          GLQ          Unf      SBrkr         NaN     Detchd       1996.0
# 289          ALQ          Unf      SBrkr          TA     Attchd       1970.0
# 290          ALQ          Unf      SBrkr          Gd     Detchd       1950.0
# 291          BLQ          Unf      SBrkr         NaN     Detchd       1973.0
#
#     GarageFinish GarageQual GarageCond  PoolQC Fence MiscFeature
# 0            Fin         TA         TA     NaN   NaN         NaN
# 1            RFn         TA         TA     NaN   NaN         NaN
# 2            RFn         TA         TA     NaN   NaN         NaN
# 3            Unf         TA         TA     NaN   NaN         NaN
# 4            Fin         TA         TA     NaN   NaN         NaN
# ..           ...        ...        ...     ...   ...         ...
# 287          RFn         TA         TA     NaN   NaN         NaN
# 288          Unf         TA         TA     NaN   NaN         NaN
# 289          Fin         TA         TA     NaN   NaN        Shed
# 290          Unf         TA         TA     NaN   NaN         NaN
# 291          Unf         TA         TA     NaN   NaN         NaN
#
# [292 rows x 19 columns]

# %% [markdown]
# There are 19 columns in Test dataset with null values

# %%
HousingDF.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
HousingDF_test.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage      45
# LotArea           0
#                  ..
# MiscVal           0
# MoSold            0
# YrSold            0
# SaleType          0
# SaleCondition     0
# Length: 80, dtype: int64

# %% [markdown]
# # Checking blank spances and random charector in each column

# %%
search = [" ","?","-"," ?"," -","? ","- "," ? "," - ","NA","N/A"," NA"," N/A","na","n/a"]

for c in HousingDF:
    for s in search:
        print(f"{s} in {c} = ", end=" ")
        print((HousingDF[c]==s).sum())
# Out:
#   in Id =  0
# ? in Id =  0
# - in Id =  0
#  ? in Id =  0
#  - in Id =  0
# ?  in Id =  0
# -  in Id =  0
#  ?  in Id =  0
#  -  in Id =  0
# NA in Id =  0
# N/A in Id =  0
#  NA in Id =  0
#  N/A in Id =  0
# na in Id =  0
# n/a in Id =  0
#   in MSSubClass =  0
# ? in MSSubClass =  0
# - in MSSubClass =  0
#  ? in MSSubClass =  0
#  - in MSSubClass =  0
# ?  in MSSubClass =  0
# -  in MSSubClass =  0
#  ?  in MSSubClass =  0
#  -  in MSSubClass =  0
# NA in MSSubClass =  0
# N/A in MSSubClass =  0
#  NA in MSSubClass =  0
#  N/A in MSSubClass =  0
# na in MSSubClass =  0
# n/a in MSSubClass =  0
#   in MSZoning =  0
# ? in MSZoning =  0
# - in MSZoning =  0
#  ? in MSZoning =  0
#  - in MSZoning =  0
# ?  in MSZoning =  0
# -  in MSZoning =  0
#  ?  in MSZoning =  0
#  -  in MSZoning =  0
# NA in MSZoning =  0
# N/A in MSZoning =  0
#  NA in MSZoning =  0
#  N/A in MSZoning =  0
# na in MSZoning =  0
# n/a in MSZoning =  0
#   in LotFrontage =  0
# ? in LotFrontage =  0
# - in LotFrontage =  0
#  ? in LotFrontage =  0
#  - in LotFrontage =  0
# ?  in LotFrontage =  0
# -  in LotFrontage =  0
#  ?  in LotFrontage =  0
#  -  in LotFrontage =  0
# NA in LotFrontage =  0
# N/A in LotFrontage =  0
#  NA in LotFrontage =  0
#  N/A in LotFrontage =  0
# na in LotFrontage =  0
# n/a in LotFrontage =  0
#   in LotArea =  0
# ? in LotArea =  0
# - in LotArea =  0
#  ? in LotArea =  0
#  - in LotArea =  0
# ?  in LotArea =  0
# -  in LotArea =  0
#  ?  in LotArea =  0
#  -  in LotArea =  0
# NA in LotArea =  0
# N/A in LotArea =  0
#  NA in LotArea =  0
#  N/A in LotArea =  0
# na in LotArea =  0
# n/a in LotArea =  0
#   in Street =  0
# ? in Street =  0
# - in Street =  0
#  ? in Street =  0
#  - in Street =  0
# ?  in Street =  0
# -  in Street =  0
#  ?  in Street =  0
#  -  in Street =  0
# NA in Street =  0
# N/A in Street =  0
#  NA in Street =  0
#  N/A in Street =  0
# na in Street =  0
# n/a in Street =  0
#   in Alley =  0
# ? in Alley =  0
# - in Alley =  0
#  ? in Alley =  0
#  - in Alley =  0
# ?  in Alley =  0
# -  in BsmtHalfBath =  0
#  ?  in BsmtHalfBath =  0
#  -  in BsmtHalfBath =  0
# NA in BsmtHalfBath =  0
# N/A in BsmtHalfBath =  0
#  NA in BsmtHalfBath =  0
#  N/A in BsmtHalfBath =  0
# na in BsmtHalfBath =  0
# n/a in BsmtHalfBath =  0
#   in FullBath =  0
# ? in FullBath =  0
# - in FullBath =  0
#  ? in FullBath =  0
#  - in FullBath =  0
# ?  in FullBath =  0
# -  in FullBath =  0
#  ?  in FullBath =  0
#  -  in FullBath =  0
# NA in FullBath =  0
# N/A in FullBath =  0
#  NA in FullBath =  0
#  N/A in FullBath =  0
# na in FullBath =  0
# n/a in FullBath =  0
#   in HalfBath =  0
# ? in HalfBath =  0
# - in HalfBath =  0
#  ? in HalfBath =  0
#  - in HalfBath =  0
# ?  in HalfBath =  0
# -  in HalfBath =  0
#  ?  in HalfBath =  0
#  -  in HalfBath =  0
# NA in HalfBath =  0
# N/A in HalfBath =  0
#  NA in HalfBath =  0
#  N/A in HalfBath =  0
# na in HalfBath =  0
# n/a in HalfBath =  0
#   in BedroomAbvGr =  0
# ? in BedroomAbvGr =  0
# - in BedroomAbvGr =  0
#  ? in BedroomAbvGr =  0
#  - in BedroomAbvGr =  0
# ?  in BedroomAbvGr =  0
# -  in BedroomAbvGr =  0
#  ?  in BedroomAbvGr =  0
#  -  in BedroomAbvGr =  0
# NA in BedroomAbvGr =  0
# N/A in BedroomAbvGr =  0
#  NA in BedroomAbvGr =  0
#  N/A in BedroomAbvGr =  0
# na in BedroomAbvGr =  0
# n/a in BedroomAbvGr =  0
#   in KitchenAbvGr =  0
# ? in KitchenAbvGr =  0
# - in KitchenAbvGr =  0
#  ? in KitchenAbvGr =  0
#  - in KitchenAbvGr =  0
# ?  in KitchenAbvGr =  0
# -  in KitchenAbvGr =  0
#  ?  in KitchenAbvGr =  0
#  -  in KitchenAbvGr =  0
# NA in KitchenAbvGr =  0
# N/A in KitchenAbvGr =  0
#  NA in KitchenAbvGr =  0
#  N/A in KitchenAbvGr =  0
# na in KitchenAbvGr =  0
# n/a in KitchenAbvGr =  0
#   in KitchenQual =  0
# ? in KitchenQual =  0
# - in KitchenQual =  0
#  ? in KitchenQual =  0
#  - in KitchenQual =  0
# ?  in KitchenQual =  0
# -  in KitchenQual =  0
#  ?  in KitchenQual =  0
#  -  in KitchenQual =  0
# NA in KitchenQual =  0
# N/A in KitchenQual =  0
#  NA in KitchenQual =  0
#  N/A in KitchenQual =  0
# na in KitchenQual =  0
# n/a in KitchenQual =  0
#   in TotRmsAbvGrd =  0
# ? in TotRmsAbvGrd =  0
# - in TotRmsAbvGrd =  0
#  ? in TotRmsAbvGrd =  0
#  - in TotRmsAbvGrd =  0
# ?  in TotRmsAbvGrd =  0
# -  in TotRmsAbvGrd =  0
#  ?  in TotRmsAbvGrd =  0
#  -  in TotRmsAbvGrd =  0
# NA in TotRmsAbvGrd =  0
# N/A in TotRmsAbvGrd =  0
#  NA in TotRmsAbvGrd =  0
#  N/A in TotRmsAbvGrd =  0
# ? in 3SsnPorch =  0
# - in 3SsnPorch =  0
#  ? in 3SsnPorch =  0
#  - in 3SsnPorch =  0
# ?  in 3SsnPorch =  0
# -  in 3SsnPorch =  0
#  ?  in 3SsnPorch =  0
#  -  in 3SsnPorch =  0
# NA in 3SsnPorch =  0
# N/A in 3SsnPorch =  0
#  NA in 3SsnPorch =  0
#  N/A in 3SsnPorch =  0
# na in 3SsnPorch =  0
# n/a in 3SsnPorch =  0
#   in ScreenPorch =  0
# ? in ScreenPorch =  0
# - in ScreenPorch =  0
#  ? in ScreenPorch =  0
#  - in ScreenPorch =  0
# ?  in ScreenPorch =  0
# -  in ScreenPorch =  0
#  ?  in ScreenPorch =  0
#  -  in ScreenPorch =  0
# NA in ScreenPorch =  0
# N/A in ScreenPorch =  0
#  NA in ScreenPorch =  0
#  N/A in ScreenPorch =  0
# na in ScreenPorch =  0
# n/a in ScreenPorch =  0
#   in PoolArea =  0
# ? in PoolArea =  0
# - in PoolArea =  0
#  ? in PoolArea =  0
#  - in PoolArea =  0
# ?  in PoolArea =  0
# -  in PoolArea =  0
#  ?  in PoolArea =  0
#  -  in PoolArea =  0
# NA in PoolArea =  0
# N/A in PoolArea =  0
#  NA in PoolArea =  0
#  N/A in PoolArea =  0
# na in PoolArea =  0
# n/a in PoolArea =  0
#   in PoolQC =  0
# ? in PoolQC =  0
# - in PoolQC =  0
#  ? in PoolQC =  0
#  - in PoolQC =  0
# ?  in PoolQC =  0
# -  in PoolQC =  0
#  ?  in PoolQC =  0
#  -  in PoolQC =  0
# NA in PoolQC =  0
# N/A in PoolQC =  0
#  NA in PoolQC =  0
#  N/A in PoolQC =  0
# na in PoolQC =  0
# n/a in PoolQC =  0
#   in Fence =  0
# ? in Fence =  0
# - in Fence =  0
#  ? in Fence =  0
#  - in Fence =  0
# ?  in Fence =  0
# -  in Fence =  0
#  ?  in Fence =  0
#  -  in Fence =  0
# NA in Fence =  0
# N/A in Fence =  0
#  NA in Fence =  0
#  N/A in Fence =  0
# na in Fence =  0
# n/a in Fence =  0
#   in MiscFeature =  0
# ? in MiscFeature =  0
# - in MiscFeature =  0
#  ? in MiscFeature =  0
#  - in MiscFeature =  0
# ?  in MiscFeature =  0
# -  in MiscFeature =  0
#  ?  in MiscFeature =  0
#  -  in MiscFeature =  0
# NA in MiscFeature =  0
# N/A in MiscFeature =  0
#  NA in MiscFeature =  0
#  N/A in MiscFeature =  0
# na in MiscFeature =  0
# n/a in MiscFeature =  0
#   in MiscVal =  0
# ? in MiscVal =  0
# - in MiscVal =  0
#  ? in MiscVal =  0
#  - in MiscVal =  0
# ?  in MiscVal =  0
# -  in MiscVal =  0
#  ?  in MiscVal =  0
#  -  in MiscVal =  0
# NA in MiscVal =  0
# N/A in MiscVal =  0
#  NA in MiscVal =  0
#  N/A in MiscVal =  0
# na in MiscVal =  0
# n/a in MiscVal =  0
#   in MoSold =  0
# ? in MoSold =  0
# - in MoSold =  0
#  ? in MoSold =  0
#  - in MoSold =  0
# ?  in MoSold =  0
# -  in MoSold =  0
#  ?  in MoSold =  0
#  -  in MoSold =  0
# NA in MoSold =  0
# N/A in MoSold =  0
#  NA in MoSold =  0
#  N/A in MoSold =  0
# na in MoSold =  0
# n/a in MoSold =  0
#   in YrSold =  0
# ? in YrSold =  0
# - in YrSold =  0
#  ? in YrSold =  0
#  - in YrSold =  0
# ?  in YrSold =  0
# -  in YrSold =  0
#  ?  in YrSold =  0
#  -  in YrSold =  0
# NA in YrSold =  0
# N/A in YrSold =  0
#  NA in YrSold =  0
#  N/A in YrSold =  0
# na in YrSold =  0
# n/a in YrSold =  0
#   in SaleType =  0
# ? in SaleType =  0
# - in SaleType =  0
#  ? in SaleType =  0
#  - in SaleType =  0
# ?  in SaleType =  0
# -  in SaleType =  0
#  ?  in SaleType =  0
#  -  in SaleType =  0
# NA in SaleType =  0
# N/A in SaleType =  0
#  NA in SaleType =  0
#  N/A in SaleType =  0
# na in SaleType =  0
# n/a in SaleType =  0
#   in SaleCondition =  0
# ? in SaleCondition =  0
# - in SaleCondition =  0
#  ? in SaleCondition =  0
#  - in SaleCondition =  0
# ?  in SaleCondition =  0
# -  in SaleCondition =  0
#  ?  in SaleCondition =  0
#  -  in SaleCondition =  0
# NA in SaleCondition =  0
# N/A in SaleCondition =  0
#  NA in SaleCondition =  0
#  N/A in SaleCondition =  0
# na in SaleCondition =  0
# n/a in SaleCondition =  0
#   in SalePrice =  0
# ? in SalePrice =  0
# - in SalePrice =  0
#  ? in SalePrice =  0
#  - in SalePrice =  0
# ?  in SalePrice =  0
# -  in SalePrice =  0
#  ?  in SalePrice =  0
#  -  in SalePrice =  0
# NA in SalePrice =  0
# N/A in SalePrice =  0
#  NA in SalePrice =  0
#  N/A in SalePrice =  0
# na in SalePrice =  0
# n/a in SalePrice =  0

# %%
#Checking special charector in test dataset

search = [" ","?","-"," ?"," -","? ","- "," ? "," - ","NA","N/A"," NA"," N/A","na","n/a"]

for c in HousingDF_test:
    for s in search:
        print(f"{s} in {c} = ", end=" ")
        print((HousingDF_test[c]==s).sum())
# Out:
#   in Id =  0
# ? in Id =  0
# - in Id =  0
#  ? in Id =  0
#  - in Id =  0
# ?  in Id =  0
# -  in Id =  0
#  ?  in Id =  0
#  -  in Id =  0
# NA in Id =  0
# N/A in Id =  0
#  NA in Id =  0
#  N/A in Id =  0
# na in Id =  0
# n/a in Id =  0
#   in MSSubClass =  0
# ? in MSSubClass =  0
# - in MSSubClass =  0
#  ? in MSSubClass =  0
#  - in MSSubClass =  0
# ?  in MSSubClass =  0
# -  in MSSubClass =  0
#  ?  in MSSubClass =  0
#  -  in MSSubClass =  0
# NA in MSSubClass =  0
# N/A in MSSubClass =  0
#  NA in MSSubClass =  0
#  N/A in MSSubClass =  0
# na in MSSubClass =  0
# n/a in MSSubClass =  0
#   in MSZoning =  0
# ? in MSZoning =  0
# - in MSZoning =  0
#  ? in MSZoning =  0
#  - in MSZoning =  0
# ?  in MSZoning =  0
# -  in MSZoning =  0
#  ?  in MSZoning =  0
#  -  in MSZoning =  0
# NA in MSZoning =  0
#  -  in LowQualFinSF =  0
# NA in LowQualFinSF =  0
# N/A in LowQualFinSF =  0
#  NA in LowQualFinSF =  0
#  N/A in LowQualFinSF =  0
# na in LowQualFinSF =  0
# n/a in LowQualFinSF =  0
#   in GrLivArea =  0
# ? in GrLivArea =  0
# - in GrLivArea =  0
#  ? in GrLivArea =  0
#  - in GrLivArea =  0
# ?  in GrLivArea =  0
# -  in GrLivArea =  0
#  ?  in GrLivArea =  0
#  -  in GrLivArea =  0
# NA in GrLivArea =  0
# N/A in GrLivArea =  0
#  NA in GrLivArea =  0
#  N/A in GrLivArea =  0
# na in GrLivArea =  0
# n/a in GrLivArea =  0
#   in BsmtFullBath =  0
# ? in BsmtFullBath =  0
# - in BsmtFullBath =  0
#  ? in BsmtFullBath =  0
#  - in BsmtFullBath =  0
# ?  in BsmtFullBath =  0
# -  in BsmtFullBath =  0
#  ?  in BsmtFullBath =  0
#  -  in BsmtFullBath =  0
# NA in BsmtFullBath =  0
# N/A in BsmtFullBath =  0
#  NA in BsmtFullBath =  0
#  N/A in BsmtFullBath =  0
# na in BsmtFullBath =  0
# n/a in BsmtFullBath =  0
#   in BsmtHalfBath =  0
# ? in BsmtHalfBath =  0
# - in BsmtHalfBath =  0
#  ? in BsmtHalfBath =  0
#  - in BsmtHalfBath =  0
# ?  in BsmtHalfBath =  0
# -  in BsmtHalfBath =  0
#  ?  in BsmtHalfBath =  0
#  -  in BsmtHalfBath =  0
# NA in BsmtHalfBath =  0
# N/A in BsmtHalfBath =  0
#  NA in BsmtHalfBath =  0
#  N/A in BsmtHalfBath =  0
# na in BsmtHalfBath =  0
# n/a in BsmtHalfBath =  0
#   in FullBath =  0
# ? in FullBath =  0
# - in FullBath =  0
#  ? in FullBath =  0
#  - in FullBath =  0
# ?  in FullBath =  0
# -  in FullBath =  0
#  ?  in FullBath =  0
#  -  in FullBath =  0
# NA in FullBath =  0
# N/A in FullBath =  0
#  NA in FullBath =  0
#  N/A in FullBath =  0
# na in FullBath =  0
# n/a in FullBath =  0
#   in HalfBath =  0
# ? in HalfBath =  0
# - in HalfBath =  0
#  ? in HalfBath =  0
#  - in HalfBath =  0
# ?  in HalfBath =  0
# -  in HalfBath =  0
#  ?  in HalfBath =  0
#  -  in HalfBath =  0
# NA in HalfBath =  0
# N/A in HalfBath =  0
#  NA in HalfBath =  0
#  N/A in HalfBath =  0
# na in HalfBath =  0
# n/a in HalfBath =  0
#   in BedroomAbvGr =  0
# ? in BedroomAbvGr =  0
# - in BedroomAbvGr =  0
#  ? in BedroomAbvGr =  0
#  - in BedroomAbvGr =  0
# ?  in BedroomAbvGr =  0
# -  in BedroomAbvGr =  0
#  ?  in BedroomAbvGr =  0
#  -  in BedroomAbvGr =  0
# NA in BedroomAbvGr =  0
# N/A in BedroomAbvGr =  0
#  NA in BedroomAbvGr =  0
#  N/A in BedroomAbvGr =  0
# na in BedroomAbvGr =  0
# n/a in BedroomAbvGr =  0
#   in KitchenAbvGr =  0
# ? in KitchenAbvGr =  0
# - in KitchenAbvGr =  0
# na in PoolQC =  0
# n/a in PoolQC =  0
#   in Fence =  0
# ? in Fence =  0
# - in Fence =  0
#  ? in Fence =  0
#  - in Fence =  0
# ?  in Fence =  0
# -  in Fence =  0
#  ?  in Fence =  0
#  -  in Fence =  0
# NA in Fence =  0
# N/A in Fence =  0
#  NA in Fence =  0
#  N/A in Fence =  0
# na in Fence =  0
# n/a in Fence =  0
#   in MiscFeature =  0
# ? in MiscFeature =  0
# - in MiscFeature =  0
#  ? in MiscFeature =  0
#  - in MiscFeature =  0
# ?  in MiscFeature =  0
# -  in MiscFeature =  0
#  ?  in MiscFeature =  0
#  -  in MiscFeature =  0
# NA in MiscFeature =  0
# N/A in MiscFeature =  0
#  NA in MiscFeature =  0
#  N/A in MiscFeature =  0
# na in MiscFeature =  0
# n/a in MiscFeature =  0
#   in MiscVal =  0
# ? in MiscVal =  0
# - in MiscVal =  0
#  ? in MiscVal =  0
#  - in MiscVal =  0
# ?  in MiscVal =  0
# -  in MiscVal =  0
#  ?  in MiscVal =  0
#  -  in MiscVal =  0
# NA in MiscVal =  0
# N/A in MiscVal =  0
#  NA in MiscVal =  0
#  N/A in MiscVal =  0
# na in MiscVal =  0
# n/a in MiscVal =  0
#   in MoSold =  0
# ? in MoSold =  0
# - in MoSold =  0
#  ? in MoSold =  0
#  - in MoSold =  0
# ?  in MoSold =  0
# -  in MoSold =  0
#  ?  in MoSold =  0
#  -  in MoSold =  0
# NA in MoSold =  0
# N/A in MoSold =  0
#  NA in MoSold =  0
#  N/A in MoSold =  0
# na in MoSold =  0
# n/a in MoSold =  0
#   in YrSold =  0
# ? in YrSold =  0
# - in YrSold =  0
#  ? in YrSold =  0
#  - in YrSold =  0
# ?  in YrSold =  0
# -  in YrSold =  0
#  ?  in YrSold =  0
#  -  in YrSold =  0
# NA in YrSold =  0
# N/A in YrSold =  0
#  NA in YrSold =  0
#  N/A in YrSold =  0
# na in YrSold =  0
# n/a in YrSold =  0
#   in SaleType =  0
# ? in SaleType =  0
# - in SaleType =  0
#  ? in SaleType =  0
#  - in SaleType =  0
# ?  in SaleType =  0
# -  in SaleType =  0
#  ?  in SaleType =  0
#  -  in SaleType =  0
# NA in SaleType =  0
# N/A in SaleType =  0
#  NA in SaleType =  0
#  N/A in SaleType =  0
# na in SaleType =  0
# n/a in SaleType =  0
#   in SaleCondition =  0
# ? in SaleCondition =  0
# - in SaleCondition =  0
#  ? in SaleCondition =  0
#  - in SaleCondition =  0
# ?  in SaleCondition =  0
# -  in SaleCondition =  0
#  ?  in SaleCondition =  0
#  -  in SaleCondition =  0
# NA in SaleCondition =  0
# N/A in SaleCondition =  0
#  NA in SaleCondition =  0
#  N/A in SaleCondition =  0
# na in SaleCondition =  0
# n/a in SaleCondition =  0

# %% [markdown]
# There are no blank spaces and special charector in test dataset

# %%
# Visuliasing null values in train dataset

sns.heatmap(HousingDF.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Columns titled: Alley, PoolQC,MiscFeature,FireplaceQu,Fence have extremely sparse data with overwhelmingly high percentage of null values and therefore must be dropped.

# %%
# Visuliasing null values in test dataset

sns.heatmap(HousingDF_test.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Columns titled: Alley, PoolQC,MiscFeature,FireplaceQu,Fence have extremely sparse data with overwhelmingly high percentage of null values and therefore must be dropped.

# %%
HousingDF.drop(columns=['Alley','PoolQC','MiscFeature','FireplaceQu','Fence'],inplace=True)

# %%
HousingDF_test.drop(columns=['Alley','PoolQC','MiscFeature','FireplaceQu','Fence'],inplace=True)

# %%
HousingDF.shape
# Out:
# (1168, 76)

# %%
HousingDF_test.shape
# Out:
# (292, 75)

# %% [markdown]
# Dropping the "ID" column from test and train dataset as they do not contribute to building a a good model for predicting the target variable values.

# %%
HousingDF.drop(columns=['Id'],inplace=True)

# %%
HousingDF_test.drop(columns=['Id'],inplace=True)

# %%
# Checking the categorical column

HousingDF.dtypes[HousingDF.dtypes=='object']
# Out:
# MSZoning         object
# Street           object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# SaleType         object
# SaleCondition    object
# dtype: object

# %%
# Checking the non-categorical column

HousingDF.dtypes[HousingDF.dtypes !='object']
# Out:
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SalePrice          int64
# dtype: object

# %%
HousingDF[HousingDF.columns[HousingDF.isnull().any()]].shape
# Out:
# (1168, 13)

# %%
HousingDF_test[HousingDF_test.columns[HousingDF_test.isnull().any()]].shape
# Out:
# (292, 14)

# %% [markdown]
# # Checking the null value percentage in each of the column in train dataset

# %%
for c in HousingDF[HousingDF.columns[HousingDF.isnull().any()]]:
    percentage = HousingDF[c].isnull().sum()/1168*100
    print(f"null value % in {c} is: {percentage}")
# Out:
# null value % in LotFrontage is: 18.32191780821918
# null value % in MasVnrType is: 0.5993150684931506
# null value % in MasVnrArea is: 0.5993150684931506
# null value % in BsmtQual is: 2.5684931506849313
# null value % in BsmtCond is: 2.5684931506849313
# null value % in BsmtExposure is: 2.654109589041096
# null value % in BsmtFinType1 is: 2.5684931506849313
# null value % in BsmtFinType2 is: 2.654109589041096
# null value % in GarageType is: 5.47945205479452
# null value % in GarageYrBlt is: 5.47945205479452
# null value % in GarageFinish is: 5.47945205479452
# null value % in GarageQual is: 5.47945205479452
# null value % in GarageCond is: 5.47945205479452

# %% [markdown]
# # Checking the null value percentage in each of the column in test dataset

# %%
for c in HousingDF_test[HousingDF_test.columns[HousingDF_test.isnull().any()]]:
    percentage = HousingDF_test[c].isnull().sum()/1168*100
    print(f"null value % in {c} is: {percentage}")
# Out:
# null value % in LotFrontage is: 3.8527397260273974
# null value % in MasVnrType is: 0.08561643835616438
# null value % in MasVnrArea is: 0.08561643835616438
# null value % in BsmtQual is: 0.5993150684931506
# null value % in BsmtCond is: 0.5993150684931506
# null value % in BsmtExposure is: 0.5993150684931506
# null value % in BsmtFinType1 is: 0.5993150684931506
# null value % in BsmtFinType2 is: 0.5993150684931506
# null value % in Electrical is: 0.08561643835616438
# null value % in GarageType is: 1.4554794520547945
# null value % in GarageYrBlt is: 1.4554794520547945
# null value % in GarageFinish is: 1.4554794520547945
# null value % in GarageQual is: 1.4554794520547945
# null value % in GarageCond is: 1.4554794520547945

# %%
HousingDF[HousingDF.columns[HousingDF.isnull().any()]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotFrontage   954 non-null    float64
#  1   MasVnrType    1161 non-null   object
#  2   MasVnrArea    1161 non-null   float64
#  3   BsmtQual      1138 non-null   object
#  4   BsmtCond      1138 non-null   object
#  5   BsmtExposure  1137 non-null   object
#  6   BsmtFinType1  1138 non-null   object
#  7   BsmtFinType2  1137 non-null   object
#  8   GarageType    1104 non-null   object
#  9   GarageYrBlt   1104 non-null   float64
#  10  GarageFinish  1104 non-null   object
#  11  GarageQual    1104 non-null   object
#  12  GarageCond    1104 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 118.8+ KB

# %% [markdown]
# Majority of the columns with null values is of object datatype

# %%
HousingDF_test[HousingDF_test.columns[HousingDF_test.isnull().any()]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LotFrontage   247 non-null    float64
#  1   MasVnrType    291 non-null    object
#  2   MasVnrArea    291 non-null    float64
#  3   BsmtQual      285 non-null    object
#  4   BsmtCond      285 non-null    object
#  5   BsmtExposure  285 non-null    object
#  6   BsmtFinType1  285 non-null    object
#  7   BsmtFinType2  285 non-null    object
#  8   Electrical    291 non-null    object
#  9   GarageType    275 non-null    object
#  10  GarageYrBlt   275 non-null    float64
#  11  GarageFinish  275 non-null    object
#  12  GarageQual    275 non-null    object
#  13  GarageCond    275 non-null    object
# dtypes: float64(3), object(11)
# memory usage: 32.1+ KB

# %% [markdown]
# Majority of the columns with null values is of object datatype

# %%
HousingDF['LotFrontage'].mode()
# Out:
# 0    60.0
# dtype: float64

# %%
# Checking the % share of most frequently occuring value.

(HousingDF['MasVnrArea']==0.0).sum()/HousingDF['MasVnrArea'].count()*100
# Out:
# 59.60378983634798

# %%
(HousingDF['MasVnrType']=='None').value_counts()
# Out:
# True     696
# False    472
# Name: MasVnrType, dtype: int64

# %% [markdown]
# # Using KNN Imputation technique for imputing missing data in LotFrontage

# %%
from sklearn.impute import KNNImputer

# %%
imp = KNNImputer(n_neighbors=2)

# %%
HousingDF[['LotFrontage']] = imp.fit_transform(HousingDF[['LotFrontage']])

# %%
HousingDF[['LotFrontage']].isnull().sum()
# Out:
# LotFrontage    0
# dtype: int64

# %% [markdown]
# There are no null values in LotFrontage column

# %%
(HousingDF['MasVnrType']==0.0).sum()/HousingDF['MasVnrType'].count()*100
# Out:
# 0.0

# %% [markdown]
# # Imputing the most frequently occuring values to NaN values in each of the column

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(missing_values = np.nan,strategy = 'most_frequent',verbose = 0)

# %%
si = si.fit(HousingDF[['MasVnrType','MasVnrArea','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond']])

# %%
HousingDF[['MasVnrType','MasVnrArea','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond']] = si.transform(HousingDF[['MasVnrType','MasVnrArea','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond']])

# %%
HousingDF.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 75, dtype: int64

# %% [markdown]
# There are no null values.
#
# # Using KNN Imputation for imputing missing data in LotFrontage in test dataset

# %%
from sklearn.impute import KNNImputer

# %%
impu = KNNImputer(n_neighbors=2)

# %%
HousingDF_test[['LotFrontage']] = impu.fit_transform(HousingDF_test[['LotFrontage']])

# %%
HousingDF_test[['LotFrontage']].isnull().sum()
# Out:
# LotFrontage    0
# dtype: int64

# %% [markdown]
# There are no null values in LotFrontage column
#
# # Imputing the most frequently occuring values to NaN values in each of the columns in Test dataset

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(missing_values = np.nan,strategy = 'most_frequent',verbose=0)

# %%
si = si.fit(HousingDF_test[['MasVnrType','Electrical','MasVnrArea','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond']])

# %%
HousingDF_test[['MasVnrType','Electrical','MasVnrArea','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond']] = si.transform(HousingDF_test[['MasVnrType','Electrical','MasVnrArea','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond']])

# %%
HousingDF_test.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 74, dtype: int64

# %% [markdown]
# # Getting the basic summary and statistical information of the data

# %%
HousingDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1168 non-null   int64
#  1   MSZoning       1168 non-null   object
#  2   LotFrontage    1168 non-null   float64
#  3   LotArea        1168 non-null   int64
#  4   Street         1168 non-null   object
#  5   LotShape       1168 non-null   object
#  6   LandContour    1168 non-null   object
#  7   Utilities      1168 non-null   object
#  8   LotConfig      1168 non-null   object
#  9   LandSlope      1168 non-null   object
#  10  Neighborhood   1168 non-null   object
#  11  Condition1     1168 non-null   object
#  12  Condition2     1168 non-null   object
#  13  BldgType       1168 non-null   object
#  14  HouseStyle     1168 non-null   object
#  15  OverallQual    1168 non-null   int64
#  16  OverallCond    1168 non-null   int64
#  17  YearBuilt      1168 non-null   int64
#  18  YearRemodAdd   1168 non-null   int64
#  19  RoofStyle      1168 non-null   object
#  20  RoofMatl       1168 non-null   object
#  21  Exterior1st    1168 non-null   object
#  22  Exterior2nd    1168 non-null   object
#  23  MasVnrType     1168 non-null   object
#  24  MasVnrArea     1168 non-null   float64
#  25  ExterQual      1168 non-null   object
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    24.000000       0.000000     0.000000     0.000000
# 75%     171.000000    70.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1168.000000   1168.000000  1168.000000  1168.000000    1168.000000
# mean      3.448630     47.315068     6.344178  2007.804795  181477.005993
# std      44.896939    543.264432     2.686352     1.329738   79105.586863
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  130375.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163995.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  215000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# Big difference between max value and 75% in SalePrice,MSSubClass,LotFrontage,LotArea,BsmtFinSF1,BsmtFinSF2, etc indicates presence of outliers.
#
# higher std than mean in columns: MasVnrArea,BsmtFinSF1,BsmtFinSF2,WoodDeckSF,OpenPorchSF,EnclosedPorch,3SsnPorch etc indicates presence of skewness.
#
# # Interpreting Relationship between Independent and Dependent Variables
#
# Analyzing the continuous data type Target column

# %%
sns.distplot(HousingDF.SalePrice)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %% [markdown]
# From the above graph it is observed that the price data forms a continuous distribution with mean of 181477.00 and tails off from 400000 mark.

# %%
HousingDF.SalePrice.skew()
# Out:
# 1.953877705368286

# %%
sns.boxplot(HousingDF.SalePrice)
# Out:
# <AxesSubplot:xlabel='SalePrice'>

# %% [markdown]
# There are outliers present in the data column
#
# # Analysing the Feature Column

# %%
plt.figure(figsize=(30,45),facecolor='white')
plotnum = 1

for col in HousingDF[HousingDF.columns[HousingDF.dtypes !='object']]:
    if plotnum <=30:
        plt.subplot(10,4,plotnum)
        sns.distplot(HousingDF[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# LotFrontage,LotArea,MasVnrArea,BsmtFinSF1,BsmtFinSF2,BsmtUnFSF,TotalBsmtSF,1stFlrSF,2ndFlrSF,GrLivArea,WoodDeckSF,OpenPorchSF,EnclosedPorch are skewed and contain outliers

# %%
HousingDF[HousingDF.columns[HousingDF.dtypes !='object']].skew()
# Out:
# MSSubClass        1.422019
# LotFrontage       2.710383
# LotArea          10.659285
# OverallQual       0.175082
# OverallCond       0.580714
# YearBuilt        -0.579204
# YearRemodAdd     -0.495864
# MasVnrArea        2.835718
# BsmtFinSF1        1.871606
# BsmtFinSF2        4.365829
# BsmtUnfSF         0.909057
# TotalBsmtSF       1.744591
# 1stFlrSF          1.513707
# 2ndFlrSF          0.823479
# LowQualFinSF      8.666142
# GrLivArea         1.449952
# BsmtFullBath      0.627106
# BsmtHalfBath      4.264403
# FullBath          0.057809
# HalfBath          0.656492
# BedroomAbvGr      0.243855
# KitchenAbvGr      4.365259
# TotRmsAbvGrd      0.644657
# Fireplaces        0.671966
# GarageYrBlt      -0.708074
# GarageCars       -0.358556
# GarageArea        0.189665
# WoodDeckSF        1.504929
# OpenPorchSF       2.410840
# EnclosedPorch     3.043610
# 3SsnPorch         9.770611
# ScreenPorch       4.105741
# PoolArea         13.243711
# MiscVal          23.065943
# MoSold            0.220979
# YrSold            0.115765
# SalePrice         1.953878
# dtype: float64

# %%
plt.figure(figsize=(30,20),facecolor = 'white')
plotnum = 1

for col in HousingDF[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch']]:
    if plotnum<=20:
        plt.subplot(8,3,plotnum)
        sns.boxplot(HousingDF[col])
        plt.xlabel(col,fontsize=15)
    plotnum+=1
plt.show()

# %% [markdown]
# Their are considerable outliers in the column
#
# # checking the skewness in data

# %%
HousingDF[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch']].skew()
# Out:
# LotFrontage       2.710383
# LotArea          10.659285
# MasVnrArea        2.835718
# BsmtFinSF1        1.871606
# BsmtFinSF2        4.365829
# BsmtUnfSF         0.909057
# TotalBsmtSF       1.744591
# 1stFlrSF          1.513707
# 2ndFlrSF          0.823479
# GrLivArea         1.449952
# GarageArea        0.189665
# WoodDeckSF        1.504929
# OpenPorchSF       2.410840
# EnclosedPorch     3.043610
# dtype: float64

# %%
plt.figure(figsize=(20,200),facecolor='white')
plotnum=1

for col in HousingDF[HousingDF.columns[HousingDF.dtypes=='object']]:
    if plotnum<=40:
        plt.subplot(40,1,plotnum)
        sns.countplot(HousingDF[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# # Following observations are made from above graphs:
#
# Residential Low Density is the most common zoing classification
#
# Most common Street Type is 'Pave'
#
# Regular is the most common LotShape, followed by Slightly irregular
#
# Most Properties have Near Flat/Level LandContour
#
# All public Utilities are available
#
# Inside lot is the most common Lot configuration
#
# Slope of property land is most commonly gentle
#
# Most Housing properties are situated in Neighborhoods of North Ames, followed by College Creek,Edwards and Old Town
#
# Most Housing properties are in proximity to Normal conditions
#
# Most Housing properties are of Single-family Detached type
#
# Most Housing properties 1 storied and 2 storied
#
# Most Houses have Gable roof style
#
# Most Houses have roofs made of Standard (Composite) Shingle
#
# Vinyl Siding is the most common exterior covering used
#
# Most Houses don't have a Masonry veneer type while some have Brick Face
#
# The quality of the material on the exterior is most commonly average/typical
#
# The present condition of the material on the exterior is most commonly average/typical
#
# Two of the most common foundation types are Cinder Block and Poured Contrete
#
# The height of the basement is usually either Typical (80-89 inches) or Good (90-99 inches)
#
# The general condition of the basement is commonly Typical with slight dampness
#
# Basements most commonly have no exposure
#
# Most houses have Basements that are usually unfinished followed by houses with basements having Good Living Quarters
#
# Most houses have Gas forced warm air furnace heating arrangement
#
# Most houses have Excellent Heating quality and condition
#
# Most houses have Central air conditioning
#
# Most houses have Standard Circuit Breakers & Romex Electrical system
#
# Most houses have Most houses have Typical/Average and Good Kitchen quality
#
# Most houses have Typical Functionality
#
# Most houses have a Garage Attached to home
#
# Most houses have an Unfinished garage
#
# Garage is usually Typical/Average
#
# Garage condition is usually Typical/Average
#
# Most houses have a Paved driveway
#
# Warranty Deed - Conventional is the most common Type of sale
#
# Condition of sale is most commonly a Normal Sale
#
#
# # Interpreting Relationship between Dependent Variable and Independent Variable Columns

# %%
plt.figure(figsize=(7,7))
HousingDF.groupby('YrSold').median()['SalePrice'].plot()
plt.title('Price Trend')
# Out:
# Text(0.5, 1.0, 'Price Trend')

# %% [markdown]
# From the graph above, it is observed that Sales value peaked between 2006 and 2007 and there has been a general downward trend in sales price since then

# %%
plt.figure(figsize=(7,7))
HousingDF.groupby('YearBuilt').median()['SalePrice'].plot()
plt.title('Price Trend')
# Out:
# Text(0.5, 1.0, 'Price Trend')

# %% [markdown]
# From the graph above, it is observed that Sales value is higher for houses built after 1990s implying the lesser the age of the house, the higher its value, however houses built between 1880 and 1900 sold for the highest, this could be because of their antiquity value.

# %%
plt.figure(figsize=(7,7))
HousingDF.groupby('YearRemodAdd').median()['SalePrice'].plot()
plt.title('Price Trend')
# Out:
# Text(0.5, 1.0, 'Price Trend')

# %% [markdown]
# From the graph above, it is observed that Sales value is higher for houses which were remodelled more recently.

# %%
plt.figure(figsize=(7,7))
HousingDF.groupby('GarageYrBlt').median()['SalePrice'].plot()
plt.title('Price Trend')
# Out:
# Text(0.5, 1.0, 'Price Trend')

# %% [markdown]
# From the graph above, it is observed that Sales value is higher for houses whose Garage was built more recently.
#
# # Extracting the age of House from YearBuilt will give a better insight into its relationship with target column data.

# %%
HousingDF['House_Age']= HousingDF['YearBuilt'].apply(lambda y: 2021-y)

# %% [markdown]
# # Extracting the age of Remodeled House from YearRemodAdd will give a better insight into its relationship with target column data.

# %%
HousingDF['Remod_Age'] = HousingDF['YearRemodAdd'].apply(lambda y:2021-y)

# %% [markdown]
# # Extracting the age of Garage of the House from GarageYrBlt will give a better insight into its relationship with target column data.

# %%
HousingDF['Garage_Age'] = HousingDF['GarageYrBlt'].apply(lambda y: 2021-y)

# %%
# Dropping the "YearBuilt", "YearRemodAdd", "GarageYrBlt"

HousingDF.drop(columns = ['YearBuilt','YearRemodAdd','GarageYrBlt'],inplace=True)

# %% [markdown]
# # Extracting the YearBuilt,YearRemodAdd, GarageYrBlt columns from the HousingDF_Test dataset

# %%
HousingDF_test['House_Age']= HousingDF_test['YearBuilt'].apply(lambda y: 2021-y)
HousingDF_test['Remod_Age'] = HousingDF_test['YearRemodAdd'].apply(lambda y:2021-y)
HousingDF_test['Garage_Age'] = HousingDF_test['GarageYrBlt'].apply(lambda y: 2021-y)

# Dropping the YearBuilt, YearRemodAdd, GarageYrBlt columns from the test data set

HousingDF_test.drop(columns = ['YearBuilt','YearRemodAdd','GarageYrBlt'],inplace=True)

# %%
plt.figure(figsize=(20,25),facecolor = 'white')
plotnum = 1

y = HousingDF['SalePrice']
HousingDF.drop(columns=['SalePrice'])

for col in HousingDF[HousingDF.columns[HousingDF.dtypes != 'object']]:
    if plotnum<=40:
        plt.subplot(10,4,plotnum)
        sns.lineplot(HousingDF[col],y)
        plt.xlabel(col,fontsize=20)
        plt.ylabel('SalePrice',fontsize=20)
    plotnum+=1
plt.tight_layout()

# %% [markdown]
# # Following Observations are made from graphs above:
#
# 1 story and 2 and 2.5 story houses built in 1946 and newer fetch the highest amount in sales.
#
# Houses with LotFrontage between 100 ft and 200 ft are sold for the highest amount.
#
# Houses wtih Lot area upto 25000 sqft fetch the highest amount.
#
# There is a Linear positive relation between Overall Quality and SalesPrice
#
# There is a Linear positive relation between Overall Condition and SalesPrice
#
# There is a Linear positive relation between Masonry veneer area and SalesPrice
#
# Most Sales were done for Type 1 Finished basement with area upto 2500 sqft
#
# There is a Linear positive relation between Type 2 Finished basement area and SalesPrice
#
# There is a Linear positive relation between Total Basement area and SalesPrice
#
# There is a Linear positive relation between Total 1st area and 2nd floor area and SalesPrice
#
# There is a Linear positive relation between low Quality finished square feet and SalesPrice
#
# There is a Linear positive relation between Above grade living area square feet and SalesPrice
#
# There is a Linear negative relation between basment half bath and SalesPrice
#
# There is a Linear positive relation between Full Bathroom and SalesPrice
#
# There is a Linear positive relation between Total rooms above grade and SalesPrice
#
# There is a Linear positive relation between Fireplaces and SalesPrice
#
# There is a Linear positive relation between Garage Car capacity and SalesPrice
#
# There is a Linear positive relation between Garage area and SalesPrice
#
# Sales Prices peaked between 0-400 square feet area for Wooden Deck
#
# Sales Prices peaked between 0-300 square feet area for Open Porch
#
# Sales Price and Enclosed Porch area have a positive relation
#
# Sales Price and 3 season Porch area have a positive relation
#
# Sales Price and screen Porch area have a positive relation
#
# Sales Price and Month Sold have a positive relation
#
# Sales Price and Month Sold have a positive relation
#
# Sales Price and house age have a negative relation
#
# Sales Price and remodelling age have a negative relation
#
# Sales Price and Garage age have a negative relation

# %%
plt.figure(figsize=(20,41),facecolor='white')
plotnum=1

y= HousingDF['SalePrice']

for col in HousingDF[HousingDF.columns[HousingDF.dtypes == 'object']]:
    if plotnum<=40:
        plt.subplot(10,4,plotnum)
        sns.barplot(HousingDF[col],y)
        plt.xlabel(col,fontsize=20)
        plt.ylabel('SalePrice',fontsize=20)
    plotnum+=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,21),facecolor='white')
plotnum=1

y = HousingDF['SalePrice']
for col in HousingDF[['Exterior1st','Exterior2nd','RoofMatl','Neighborhood']]:
    if plotnum<=4:
        plt.subplot(4,1,plotnum)
        sns.barplot(HousingDF[col],y)
        plt.xlabel(col,fontsize=20)
        plt.ylabel('SalePrice',fontsize=20)
    plotnum+=1
plt.tight_layout()

# %% [markdown]
# # Following Observations are made from graphs above:
#
# Saleprice is highest for Floating Village and Low density Residential zones
#
# Saleprice is highest for housing properties near paved streets
#
# Saleprice is highest for irregular lot shapes
#
# Hill side properties sell for the highest amount
#
# Utilities and Landslope columns don't show a strong relationship with Sales Price
#
# Housing Properties in Northridge, Stone Brook,Northridge Heights,Timberland, Somerset,Veenker fetch the highest Sales amount
#
# Cul-de-sac and 3 sided frontage lot configurations fetch the highest Sales amount
#
# Proximity to Railroads, Off-site features like parks etc fetch the highest Sales amount
#
# Townhouse and Single-family Detached are the most valued
#
# Two story and Two and one-half story: 2nd level finished sell for the highest amount
#
# Houses with Wood Shingle Roofs sell for the highest amount
#
# Houses with Exterior covering of Cement Board,Stone,Imitation Stucco sell for the highest amount
#
# Houses with Stone Mason veneer type sell for the highest amount
#
# Houses with Excellent exterior material quality sell for the highest amount
#
# Houses with Excellent exterior material condition  sell for the highest amount
#
# Houses with Poured Contrete and stone foundation types sell for the highest amount
#
# Houses with Excellent (100+ inches) height of the basement sell for the highest amount
#
# Houses with Excellent Basement Condition sell for the highest amount
#
# Houses with Good  Basement Exposure sell for the highest amount
#
# Houses with Good and Average Living Quarters in Basement sell for the highest amount
#
# Houses with Gas forced warm air furnace and Gas hot water heating systems sell for the highest amount
#
# Houses with Excellent Heating quality and condition sell for the highest amount
#
# Houses with Central Air Conditioning sell for the highest amount
#
# Houses with Standard Circuit Breakers & Romex sell for the highest amount
#
# Houses with Excellent Kitchen Quality sell for the highest amount
#
# Houses with Built in Garages sell for the highest amount
#
# Houses with Good / Typical Garage condition sell for the highest amount
#
# Houses with Finished Garage sell for the highest amount
#
# Houses with excellent Garage Quality sell for the highest amount
#
# Houses with Paved Driveway sell for the highest amount
#
# Homes just constructed and sold, Contract 15% Down payment regular terms sell for the highest amount
#
# New Homes(not completed when last assessed) sell for the highest amount

# %%
sns.barplot(HousingDF['MSZoning'],HousingDF['SalePrice'],hue= HousingDF['SaleCondition'])
# Out:
# <AxesSubplot:xlabel='MSZoning', ylabel='SalePrice'>

# %% [markdown]
# New Homes are the most popular in all types of zoning

# %%
sns.barplot(HousingDF['MSZoning'],HousingDF['SalePrice'],hue = HousingDF['SaleType'])
# Out:
# <AxesSubplot:xlabel='MSZoning', ylabel='SalePrice'>

# %% [markdown]
# New hourses and Low interest contract are the most popular sale types in low density, medium density and floating village residentials.

# %%
sns.barplot(HousingDF['MSZoning'],HousingDF['SalePrice'],hue = HousingDF['LotShape'])
# Out:
# <AxesSubplot:xlabel='MSZoning', ylabel='SalePrice'>

# %% [markdown]
# Partially irregular and irregular plot shapes are most popular in low and medium residential zones

# %%
sns.barplot(HousingDF['MSZoning'],HousingDF['SalePrice'],hue = HousingDF['LandContour'])
# Out:
# <AxesSubplot:xlabel='MSZoning', ylabel='SalePrice'>

# %% [markdown]
# Low density and medium density zones settled near hillsides and depressions are mostly sold at higher prices, whereas floating villages are settled in flat regions, and high density zones settle near banked regions sell for the highest prices

# %%
plt.figure(figsize=(18,7),facecolor = 'white')
sns.barplot(HousingDF['Neighborhood'],HousingDF['SalePrice'],hue = HousingDF['LandContour'])
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='SalePrice'>

# %% [markdown]
# Most housing properties established in levelled regions in North Ridge sell for the highest.
#
# Most Housing properties in levelled regions of Stone Brook sell for highest followed by banked region and hillsides.
#
# Houses in levelled region of NorthRidge heights sell for the most while housing properties in depressed regions of Veenker sell for the highest prices.

# %%
plt.figure(figsize=(18,7),facecolor='white')
sns.barplot(HousingDF['Neighborhood'],HousingDF['SalePrice'],hue = HousingDF['SaleCondition'])
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='SalePrice'>

# %% [markdown]
# Most housing properties that are newly established in Crawford,Stone Brook, Timberlane,North Ridge Heights,Bloomington Heights sell for the highest.
#
# Most Housing properties in North Ridge sell for trade, foreclosure, short sale and normal sale in North Ridge

# %%
plt.figure(figsize=(18,7),facecolor='white')
sns.barplot(HousingDF['Neighborhood'],HousingDF['SalePrice'],hue = HousingDF['MSZoning'])
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='SalePrice'>

# %% [markdown]
# Most houses sold in North Ridge,North Ridge Heights, Somerset,TimberLane,Veenker, Bloomington Heights are in low density residential zones.
#
# North Ames has more houses sold in High density residential zones, while Crawford has more houses sold in medium density residential zones.

# %%
plt.figure(figsize=(18,7),facecolor='white')
sns.barplot(HousingDF['Neighborhood'],HousingDF['SalePrice'],hue = HousingDF['SaleType'])
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='SalePrice'>

# %% [markdown]
# Warranty Deed - Conventional,Home just constructed and sold,Contract Low InterestCourt Officer Deed/Estate are the most common sale types.

# %%
sns.barplot(HousingDF['Heating'],HousingDF['SalePrice'],hue = HousingDF['HeatingQC'])
# Out:
# <AxesSubplot:xlabel='Heating', ylabel='SalePrice'>

# %% [markdown]
# Excelent quality of Gas forced warm air furnace and Gas hot water heating systems fetches the highest amount of money.

# %%
sns.barplot(HousingDF['LotConfig'],HousingDF['SalePrice'],hue = HousingDF['LotShape'])
# Out:
# <AxesSubplot:xlabel='LotConfig', ylabel='SalePrice'>

# %% [markdown]
# 3 sided Frontage properties with Regular plot shape sell for the highest

# %%
sns.barplot(HousingDF['HouseStyle'],HousingDF['SalePrice'],hue = HousingDF['BldgType'])
# Out:
# <AxesSubplot:xlabel='HouseStyle', ylabel='SalePrice'>

# %% [markdown]
# Two and one-half story: 2nd level finished housing properties sell for the highest.

# %%
plt.figure(figsize=(18,7),facecolor='white')
sns.barplot(HousingDF['Neighborhood'],HousingDF['SalePrice'],hue = HousingDF['BldgType'])
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='SalePrice'>

# %% [markdown]
# Single-family Detached housing properties sell for the highest in most neighborhoods
#
# # Encoding Categorical Columns
#
# # Encoding using Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labenc = LabelEncoder()

# %%
for col in HousingDF[HousingDF.columns[HousingDF.dtypes == 'object']]:
    HousingDF[col] = labenc.fit_transform(HousingDF[col])

# %%
# Encoding years in YrSold column

HousingDF['YrSold'] = HousingDF.YrSold.map({2007:2,2009:4,2006:1,2008:3,2010:5})

# %%
HousingDF['Utilities'] = HousingDF.Utilities.map({0:1})

# %%
HousingDF.dtypes[HousingDF.dtypes != 'object']
# Out:
# MSSubClass         int64
# MSZoning           int32
# LotFrontage      float64
# LotArea            int64
# Street             int32
#                   ...
# SaleCondition      int32
# SalePrice          int64
# House_Age          int64
# Remod_Age          int64
# Garage_Age       float64
# Length: 75, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

labenc = LabelEncoder()

for col in HousingDF_test[HousingDF_test.columns[HousingDF_test.dtypes == 'object']]:
    HousingDF_test[col] = labenc.fit_transform(HousingDF_test[col])
    
HousingDF_test['YrSold'] = HousingDF_test.YrSold.map({2007:2,2009:4,2006:1, 2008: 3, 2010: 5}) # encoding years in YrSold Column

HousingDF_test['Utilities'] =HousingDF_test.Utilities.map({0:1})

HousingDF_test.dtypes[HousingDF_test.dtypes != 'object']
# Out:
# MSSubClass         int64
# MSZoning           int32
# LotFrontage      float64
# LotArea            int64
# Street             int32
#                   ...
# SaleType           int32
# SaleCondition      int32
# House_Age          int64
# Remod_Age          int64
# Garage_Age       float64
# Length: 74, dtype: object

# %% [markdown]
# # Finding Correlation between feature and target columns

# %%
h_corr = HousingDF.corr()

# %%
h_corr
# Out:
#                MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# MSSubClass       1.000000  0.007478    -0.336681 -0.124151 -0.035981
# MSZoning         0.007478  1.000000    -0.069661 -0.023328  0.140215
# LotFrontage     -0.336681 -0.069661     1.000000  0.299452 -0.035309
# LotArea         -0.124151 -0.023328     0.299452  1.000000 -0.263973
# Street          -0.035981  0.140215    -0.035309 -0.263973  1.000000
# ...                   ...       ...          ...       ...       ...
# SaleCondition   -0.028981  0.004501     0.065091  0.034236  0.014176
# SalePrice       -0.060775 -0.133221     0.323779  0.249499  0.044753
# House_Age       -0.023988  0.299732    -0.112655 -0.005506 -0.020292
# Remod_Age       -0.056618  0.174586    -0.088799 -0.027228 -0.057866
# Garage_Age      -0.093390  0.243359    -0.027832  0.054091 -0.001096
#
#                LotShape  LandContour  Utilities  LotConfig  LandSlope  ...  \
# MSSubClass     0.104485    -0.021387        NaN   0.076880  -0.014930  ...
# MSZoning       0.053655     0.001175        NaN  -0.027246  -0.023952  ...
# LotFrontage   -0.144523    -0.073451        NaN  -0.192468   0.046051  ...
# LotArea       -0.189201    -0.159038        NaN  -0.152063   0.395410  ...
# Street        -0.012941     0.105226        NaN   0.000153  -0.141572  ...
# ...                 ...          ...        ...        ...        ...  ...
# SaleCondition -0.054905     0.047715        NaN   0.043692  -0.061461  ...
# SalePrice     -0.248171     0.032836        NaN  -0.060452   0.015485  ...
# House_Age      0.230080    -0.153721        NaN  -0.012933   0.085931  ...
# Remod_Age      0.155428    -0.086936        NaN   0.009281   0.048599  ...
# Garage_Age     0.163505    -0.098544        NaN   0.001410   0.071849  ...
#
#                PoolArea   MiscVal    MoSold    YrSold  SaleType  \
# MSSubClass     0.009583 -0.023503 -0.016015 -0.038595  0.035050
# MSZoning      -0.001663  0.003416 -0.051646 -0.004964  0.079854
# LotFrontage    0.196001 -0.001329  0.022517 -0.003885 -0.035356
# LotArea        0.097107  0.051679  0.015141 -0.035399  0.005421
# Street         0.004505 -0.030354 -0.008860 -0.019635  0.025920
# ...                 ...       ...       ...       ...       ...
# SaleCondition -0.074354  0.012178 -0.003462  0.024505  0.143557
# SalePrice      0.103280 -0.013071  0.072764 -0.045508 -0.050851
# House_Age     -0.006408  0.030008 -0.031754  0.013976  0.062720
# Remod_Age     -0.006874  0.001199 -0.024663 -0.033265 -0.020832
# Garage_Age     0.019283  0.037872  0.010998  0.008951  0.021710
#
#                SaleCondition  SalePrice  House_Age  Remod_Age  Garage_Age
# MSSubClass         -0.028981  -0.060775  -0.023988  -0.056618   -0.093390
# MSZoning            0.004501  -0.133221   0.299732   0.174586    0.243359
# LotFrontage         0.065091   0.323779  -0.112655  -0.088799   -0.027832
# LotArea             0.034236   0.249499  -0.005506  -0.027228    0.054091
# Street              0.014176   0.044753  -0.020292  -0.057866   -0.001096
# ...                      ...        ...        ...        ...         ...
# SaleCondition       1.000000   0.217687  -0.212597  -0.227400   -0.147132
# SalePrice           0.217687   1.000000  -0.514408  -0.507831   -0.381997
# House_Age          -0.212597  -0.514408   1.000000   0.592829    0.702527
# Remod_Age          -0.227400  -0.507831   0.592829   1.000000    0.562284
# Garage_Age         -0.147132  -0.381997   0.702527   0.562284    1.000000
#
# [75 rows x 75 columns]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(h_corr,annot=True,linewidth=1)
plt.show()

# %% [markdown]
# # Visualizing correlation of feature columns with label column.

# %%
plt.figure(figsize = (20,8))
HousingDF.corr()['SalePrice'].sort_values(ascending = False).drop(['SalePrice']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('SalePrice',fontsize=15)
plt.title('correlation',fontsize = 18)
plt.show()

# %% [markdown]
# OverallQual,GrLiveArea,GarageCars,GarageArea,TotalBsmtSF,1stFlrSF,FullBath,TotRmsAbvGrd,MasVnrArea,FirePlaces have the strongest positive correlation with SalePrice while BsmtQual,ExterQual,KitchenQual,GarageFinish,House_age,Remod_age,HeatingQC,Garage_age have the strongest negative correlation with SalePrice.
#
# Dropping column 'Utilities' since it doesn't contribute to building a good model for predicting the target variable values.

# %%
HousingDF.drop(columns = ['Utilities'],inplace=True)

# %%
HousingDF_test.drop(columns = ['Utilities'],inplace=True)

# %% [markdown]
# # Removing Outliers in continuous data type columns using Z score Method

# %%
#making a copy of the continuous data type columns with outliers.

df2 =HousingDF[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch']].copy()

# %%
from scipy.stats import zscore
zscor = zscore(df2)
z_score_abs = np.abs(zscor)

df3 = df2[(z_score_abs < 3).all(axis=1)] #taking 3 as threshold value

# %%
df3.shape
# Out:
# (1006, 14)

# %%
df2.shape
# Out:
# (1168, 14)

# %%
# Checking data loss %

loss = (1168-1006)/1168*100
loss
# Out:
# 13.86986301369863

# %% [markdown]
# 13.86% data loss is not acceptable therefore outliers will not be removed.
#
# # Normalizing Data Distribution using PowerTransformer

# %%
plt.figure(figsize=(30,45),facecolor='white')
plotnum=1

for col in HousingDF[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','House_Age','Remod_Age','Garage_Age']]:
    if plotnum<=30:
        plt.subplot(10,4,plotnum)
        sns.distplot(HousingDF[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %%
HousingDF[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','House_Age','Remod_Age','Garage_Age']].skew()
# Out:
# LotFrontage       2.710383
# LotArea          10.659285
# MasVnrArea        2.835718
# BsmtFinSF1        1.871606
# BsmtFinSF2        4.365829
# BsmtUnfSF         0.909057
# TotalBsmtSF       1.744591
# 1stFlrSF          1.513707
# 2ndFlrSF          0.823479
# GrLivArea         1.449952
# GarageArea        0.189665
# WoodDeckSF        1.504929
# OpenPorchSF       2.410840
# EnclosedPorch     3.043610
# House_Age         0.579204
# Remod_Age         0.495864
# Garage_Age        0.708074
# dtype: float64

# %% [markdown]
# Data Distributions are skewed.

# %%
from sklearn.preprocessing import PowerTransformer

# %%
powtrns = PowerTransformer(method = 'yeo-johnson', standardize = True)

# %%
df4 = HousingDF[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch']]

# %%
transformed= powtrns.fit_transform(df4)
type(transformed)
# Out:
# numpy.ndarray

# %%
transformed = pd.DataFrame(transformed, columns=df4.columns) #to convert numpy array back into dataframe
transformed.skew()
# Out:
# LotFrontage      0.161368
# LotArea          0.032509
# MasVnrArea       0.439526
# BsmtFinSF1      -0.404528
# BsmtFinSF2       2.394737
# BsmtUnfSF       -0.284390
# TotalBsmtSF      0.286779
# 1stFlrSF        -0.002391
# 2ndFlrSF         0.280208
# GrLivArea       -0.000054
# GarageArea      -0.320370
# WoodDeckSF       0.113026
# OpenPorchSF     -0.002749
# EnclosedPorch    2.022616
# dtype: float64

# %%
transformed.index = HousingDF.index

HousingDF[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch']] = transformed[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch']]

HousingDF[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','House_Age','Remod_Age','Garage_Age']].skew()
# Out:
# LotFrontage      0.161368
# LotArea          0.032509
# MasVnrArea       0.439526
# BsmtFinSF1      -0.404528
# BsmtFinSF2       2.394737
# BsmtUnfSF       -0.284390
# TotalBsmtSF      0.286779
# 1stFlrSF        -0.002391
# 2ndFlrSF         0.280208
# GrLivArea       -0.000054
# GarageArea      -0.320370
# WoodDeckSF       0.113026
# OpenPorchSF     -0.002749
# EnclosedPorch    2.022616
# House_Age        0.579204
# Remod_Age        0.495864
# Garage_Age       0.708074
# dtype: float64

# %% [markdown]
# A lot of skewness has been removed.

# %%
from sklearn.preprocessing import PowerTransformer

powtrans= PowerTransformer(method='yeo-johnson', standardize=True)

# %%
df4 = HousingDF_test[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch']]

# %%
transformed= powtrans.fit_transform(df4)

type(transformed)

transformed = pd.DataFrame(transformed, columns=df4.columns) #to convert numpy array back into dataframe

# %%
transformed.skew()
# Out:
# LotFrontage      0.096846
# LotArea          0.003111
# MasVnrArea       0.376082
# BsmtFinSF1      -0.441605
# BsmtFinSF2       2.570199
# BsmtUnfSF       -0.232099
# TotalBsmtSF     -0.037982
# 1stFlrSF        -0.000548
# 2ndFlrSF         0.284246
# GrLivArea       -0.000307
# GarageArea      -0.361092
# WoodDeckSF       0.210102
# OpenPorchSF     -0.058951
# EnclosedPorch    2.165535
# dtype: float64

# %%
transformed.index = HousingDF_test.index

# %%
HousingDF_test[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch']] = transformed[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch']]

# %%
HousingDF_test[['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','House_Age','Remod_Age','Garage_Age']].skew()
# Out:
# LotFrontage      0.096846
# LotArea          0.003111
# MasVnrArea       0.376082
# BsmtFinSF1      -0.441605
# BsmtFinSF2       2.570199
# BsmtUnfSF       -0.232099
# TotalBsmtSF     -0.037982
# 1stFlrSF        -0.000548
# 2ndFlrSF         0.284246
# GrLivArea       -0.000307
# GarageArea      -0.361092
# WoodDeckSF       0.210102
# OpenPorchSF     -0.058951
# EnclosedPorch    2.165535
# House_Age        0.755233
# Remod_Age        0.535600
# Garage_Age       0.742835
# dtype: float64

# %% [markdown]
# # Feature Selection

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = HousingDF.drop(columns = ['SalePrice'])
y = HousingDF['SalePrice']

# %%
scaler = StandardScaler()
scaled_x = scaler.fit_transform(X)

# %% [markdown]
# # Checking the Multicollinearity using variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()

# %%
vif["Features"] = X.columns
vif['vif'] = [variance_inflation_factor(scaled_x,i) for i in range(scaled_x.shape[1])]

# %%
vif
# Out:
#          Features       vif
# 0      MSSubClass  5.507317
# 1        MSZoning  1.382987
# 2     LotFrontage  2.174714
# 3         LotArea  2.900531
# 4          Street  1.131134
# ..            ...       ...
# 68       SaleType  1.121925
# 69  SaleCondition  1.199333
# 70      House_Age  8.061473
# 71      Remod_Age  2.933032
# 72     Garage_Age  2.888644
#
# [73 rows x 2 columns]

# %% [markdown]
# # Principal Component Analysis

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA()
principleComponents = pca.fit_transform(scaled_x)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Variance %')
plt.title('Explained Variance')
plt.show()

# %% [markdown]
# 70 components explain around 95% variance in Data
#
# # Selecting Kbest Features

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# %%
bestfeat = SelectKBest(score_func = f_classif, k = 'all')
fit = bestfeat.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

# %%
fit = bestfeat.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
dfcolumns.head()
featureScores = pd.concat([dfcolumns,dfscores],axis = 1)
featureScores.columns = ['Feature', 'Score']
print(featureScores.nlargest(75,'Score'))
# Out:
#         Feature     Score
# 14  OverallQual  5.303071
# 65      MiscVal  3.564855
# 22    ExterQual  3.514221
# 41    GrLivArea  2.956955
# 25     BsmtQual  2.876879
# ..          ...       ...
# 10   Condition1  0.803848
# 50   Functional  0.797839
# 31   BsmtFinSF2  0.793233
# 11   Condition2  0.782965
# 68     SaleType  0.778011
#
# [73 rows x 2 columns]

# %%
X.shape
# Out:
# (1168, 73)

# %% [markdown]
# # Selecting best features based on their scores:

# %%
x_best = X.drop(columns = ['SaleType','Condition2','BsmtFinSF2']).copy()

# %%
scaled_x_best = scaler.fit_transform(x_best)

# %% [markdown]
# This is a Regression Problem since Target/ Label column ('SalePrice') has Continuous type of Data.
#
# # Regression Model Building

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# # Finding the Best Random State

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
maxAcc = 0
maxRs = 0

for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(scaled_x_best,y,test_size = .25, random_state = i)
    modRF = RandomForestRegressor()
    modRF.fit(x_train,y_train)
    pred = modRF.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc>maxAcc:
        maxAcc = acc
        maxRs = i

print(f"Best Accuracy is: {maxAcc} on random_state : {maxRs}")
# Out:
# Best Accuracy is: 0.9158495827351104 on random_state : 72

# %%
x_train,x_test,y_train,y_test = train_test_split(scaled_x_best,y,test_size = .25, random_state = 72)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
rf = RandomForestRegressor()
dt = DecisionTreeRegressor()
xg = XGBRegressor()
SV= SVR()
r=Ridge()

# %% [markdown]
# # Training the Models

# %%
rf.fit(x_train,y_train)
xg.fit(x_train,y_train)
SV.fit(x_train,y_train)
r.fit(x_train,y_train)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# All models have been trained.
#
# # Ridge Regression Model

# %%
y_r_pred = r.predict(x_test)

# %%
# R2 Score

r2_score(y_test,y_r_pred)
# Out:
# 0.8581092136367106

# %%
# Mean Squared Error

mean_squared_error(y_test,y_r_pred)
# Out:
# 860008392.6691436

# %%
# Root Mean Squared Error

np.sqrt(mean_squared_error(y_test,y_r_pred))
# Out:
# 29325.899690702474

# %% [markdown]
# # Random Forest Regression Model

# %%
y_rf_pred = rf.predict(x_test)

# %%
# R2 Score

r2_score(y_test,y_rf_pred)
# Out:
# 0.9198255082212908

# %%
# Mean Squared Error

mean_squared_error(y_test,y_rf_pred)
# Out:
# 485942305.16938186

# %%
# Root Mean Squared Error

np.sqrt(mean_squared_error(y_test,y_rf_pred))
# Out:
# 22044.09910087917

# %% [markdown]
# # XGB Regression Model

# %%
y_xg_pred = xg.predict(x_test)

# %%
# R2 Score

r2_score(y_test,y_xg_pred)
# Out:
# 0.8990045700516924

# %%
# Mean Squared Error

mean_squared_error(y_test,y_xg_pred)
# Out:
# 612139234.7096407

# %%
# Root Mean Squared Error

np.sqrt(mean_squared_error(y_test,y_xg_pred))
# Out:
# 24741.447708443433

# %% [markdown]
# # Support Vector Regression Model

# %%
y_svr_pred = SV.predict(x_test)

# %%
# R2 Score

r2_score(y_test,y_svr_pred)
# Out:
# -0.061666480005083235

# %%
# Mean Squared Error

mean_squared_error(y_test,y_svr_pred)
# Out:
# 6434822911.490364

# %%
# Root Mean Squared Error

np.sqrt(mean_squared_error(y_test,y_svr_pred))
# Out:
# 80217.34794600458

# %% [markdown]
# # Decission Tree Regression Model

# %%
y_dt_pred = dt.predict(x_test)

# %%
# R2 Score

r2_score(y_test,y_dt_pred)
# Out:
# 0.805067616563546

# %%
# Mean Squared Error

mean_squared_error(y_test,y_dt_pred)
# Out:
# 1181496628.8869863

# %%
# Root Mean Squared Error

np.sqrt(mean_squared_error(y_test,y_dt_pred))
# Out:
# 34372.90544727033

# %% [markdown]
# # Model Cross Validation

# %%
from sklearn.model_selection import ShuffleSplit, cross_val_score

# %% [markdown]
# # Ridge Regression Model

# %%
cross_val_score(r,scaled_x_best,y,cv=5).mean()
# Out:
# 0.7724187373088185

# %% [markdown]
# # Random Forest Regression

# %%
cross_val_score(rf,scaled_x_best,y,cv=5).mean()
# Out:
# 0.8470150918799064

# %% [markdown]
# # XGB Regression Model

# %%
cross_val_score(xg,scaled_x_best,y,cv=5).mean()
# Out:
# 0.8317857020177609

# %% [markdown]
# # SV Regression Model

# %%
cross_val_score(SV,scaled_x_best,y,cv=5).mean()
# Out:
# -0.06178097265098006

# %% [markdown]
# # Decission Tree Model

# %%
cross_val_score(dt,scaled_x_best,y,cv=5).mean()
# Out:
# 0.6982375221719971

# %% [markdown]
# # Based on comparing Accuracy Score results with Cross Validation results, it is determined that Random Forest Regressor is the best model. It also has the lowest Root Mean Squared Error score
#
# # Random Forest Regressor

# %%
parameter = {'n_estimators':[30,60,80],'max_depth': [10,20,40],'min_samples_leaf':[1,2,5,10,20,30],'min_samples_split':[5,10,20],'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}

# %%
GridCV = GridSearchCV(RandomForestRegressor(),parameter,cv=5,n_jobs = -1,verbose = 1)

# %%
GridCV.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 972 candidates, totalling 4860 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': [10, 20, 40],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 5, 10, 20, 30],
#                          'min_samples_split': [5, 10, 20],
#                          'n_estimators': [30, 60, 80]},
#              verbose=1)

# %%
GridCV.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 40,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 80}

# %%
Best_mod = RandomForestRegressor(n_estimators = 80,criterion = 'mse', max_depth= 40, max_features = 'sqrt',min_samples_leaf = 1, min_samples_split = 5)

# %%
Best_mod.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=40, max_features='sqrt', min_samples_split=5,
#                       n_estimators=80)

# %%
rfpred = Best_mod.predict(x_test)
acc = r2_score(y_test,rfpred)
print(acc*100)
# Out:
# 90.76416628748633

# %% [markdown]
# Random Forest Regressor has an accuracy of 90.76%
#
# Saving The Model

# %%
import joblib
joblib.dump(Best_mod,"BestModelPFA.pkl")
# Out:
# ['BestModelPFA.pkl']

# %% [markdown]
# # Preparing the Test Dataset

# %%
xtest_best = HousingDF_test.drop(columns=['SaleType','Condition2','BsmtFinSF2']).copy()

# %%
scaled_xtest_best = scaler.fit_transform(xtest_best)

# %% [markdown]
# # Loading the Model

# %%
mod=joblib.load("BestModelPFA.pkl")

# %%
print(mod.predict(scaled_xtest_best))
# Out:
# [339259.28348214 205170.15758433 262860.79834325 167462.4812996
#  251199.51742244  90217.8189881  148080.5062004  324682.95979663
#  254708.22512942 164780.4544099   91504.75440431 143510.45320437
#  128309.96159722 198939.20988907 306273.33960317 132051.55634921
#  118195.35952381 128352.0806746  174173.10610615 196839.93029762
#  158000.61728175 154153.94246032 149044.1058667  118200.65214782
#  103816.17374008 128768.13750992 178443.88294795 146395.01354167
#  173770.43500992 114483.94930465 142161.26541667 195206.50099206
#  233559.62664683 164475.97519841 124277.2034623  177640.16429067
#  197265.82585588 117934.53142857 160118.95770833 150677.57507937
#  108256.23577381 316542.63991071 208013.70176091 189182.43410489
#  147037.29029762 132311.26564755 132429.12852183 108964.2202877
#  209940.13955357 324634.0420322  147902.30720238 203597.58735435
#  108679.73831349 102641.33958333 296026.70051091 125997.15690476
#  145585.97098485 183420.9516121  125042.65609217 248727.67559389
#  107155.12068452 177558.0625496  130164.79496032 150713.31222944
#  200088.28935786 109569.69561508 156907.39655754 196183.79334416
#  141081.95262897 167820.90646645 287681.35842262 165326.8015873
#  171168.99253968 156626.31966721 152376.57844246 230745.97101822
#  320719.56494589 200619.70560516 275553.6244246  142470.60079365
#  209385.39045139 148213.80304924 149839.37738636 160793.34575893
#  185586.87563492 231642.46394841 117524.55785534 338419.76733135
#  154902.56257215 181277.62359758 248066.8965873  132046.92481512
#  139905.73125992 124327.5791369  186174.56035714 163997.23003968
#  253859.11479437 171181.72305871 323662.41980159 123938.36850559
#  252252.39620536 107802.59525253 118877.03125721 165805.94508027
#  191944.42470058 140965.27089286 282253.06957882 155535.84582341
#  193131.11495536 192541.7378373  200998.50397817 167953.10960317
#  198889.66820437 243238.84169147 135145.92857143 116515.21169102
#  129200.33556548 191434.28342262 149992.37585317 119044.06162698
